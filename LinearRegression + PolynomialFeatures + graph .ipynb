# %%
import numpy as np
X=np.array([258,270,294,320,342,368,396,446,480,586])[:,np.newaxis]
y=np.array([236.4,234.4,252.8,298.6,314.2,342.2,360.8,368,391.2,390.8])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
p1=PolynomialFeatures(degree=2)
x_p1=pl.fit_transform(X)

# %%
pr=LinearRegression()
pr.fit(x_p1,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
test=np.arange(260,600,2)[:,np.newaxis]

# %%
y1=lr.predict(test)
test1=p1.fit_transform(test)
y2=pr.predict(test1)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(test,y1,c='red')
plt.plot(test,y2,c='black')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,r2_score
print("Linear :",mean_squared_error(lr.predict(X),y))
print("Polynomial",mean_squared_error(pr.predict(x_p1),y))
# Out:
# Linear : 569.7796663183207
# Polynomial 61.330214517447715

# %%
print("Accuracy")
print("Linear",r2_score(lr.predict(X),y))
print("Polynomial",r2_score(pr.predict(x_p1),y))
# Out:
# Accuracy
# Linear 0.7976511641127627
# Polynomial 0.9815508176225227
