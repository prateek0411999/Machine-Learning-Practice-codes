# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("forestfires.csv")

# %%
#first five rows and tail for back se dekhne k liye
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df.isnull().sum()
## to find the missing values
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %%
#displays the no. of rowsandcol
df.shape
# Out:
# (517, 13)

# %%
#LABEL ENCODING - 
#df=pd.get_dummies(df["month"])

# %%
df.head(5)
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ### import LabelEncoder for labeling the strings into numeric values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
sagar=LabelEncoder()

# %%
df["month"]=sagar.fit_transform(df["month"])

# %%
df["day"]=sagar.fit_transform(df["day"])

# %%
df[["month"]]
# Out:
#      month
# 0        7
# 1       10
# 2       10
# 3        7
# 4        7
# 5        1
# 6        1
# 7        1
# 8       11
# 9       11
# 10      11
# 11      11
# 12       1
# 13      11
# 14      11
# 15      11
# 16       7
# 17      10
# 18       7
# 19       0
# 20      11
# 21      11
# 22       6
# 23       1
# 24       1
# 25       1
# 26      11
# 27      11
# 28      11
# 29      11
# ..     ...
# 487      1
# 488      1
# 489      1
# 490      1
# 491      1
# 492      1
# 493      1
# 494      1
# 495      1
# 496      1
# 497      1
# 498      1
# 499      1
# 500      1
# 501      1
# 502      1
# 503      1
# 504      1
# 505      1
# 506      1
# 507      1
# 508      1
# 509      1
# 510      1
# 511      1
# 512      1
# 513      1
# 514      1
# 515      1
# 516      9
#
# [517 rows x 1 columns]

# %%
#df["month"]=pd.get_dummies(df["month"])

# %%
#df["day"]=pd.get_dummies(df["day"])

# %%
df.head()
# Out:
#    X  Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5      7    0  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4     10    5  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4     10    2  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6      7    0  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6      7    3  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df.head()
# Out:
#    X  Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5      7    0  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4     10    5  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4     10    2  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6      7    0  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6      7    3  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ### label endcoder se month aur day ko values dedi

# %%
df.describe()
## to find the min, max and all in all the columns
# Out:
#                 X           Y       month         day        FFMC         DMC  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807    5.758221    2.736944   90.644681  110.872340
# std      2.313778    1.229900    4.373275    1.925061    5.520111   64.046482
# min      1.000000    2.000000    0.000000    0.000000   18.700000    1.100000
# 25%      3.000000    4.000000    1.000000    1.000000   90.200000   68.600000
# 50%      4.000000    4.000000    6.000000    3.000000   91.600000  108.300000
# 75%      7.000000    5.000000   11.000000    4.000000   92.900000  142.400000
# max      9.000000    9.000000   11.000000    6.000000   96.200000  291.300000
#
#                DC         ISI        temp          RH        wind        rain  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean   547.940039    9.021663   18.889168   44.288201    4.017602    0.021663
# ...

# %%
#data preprocessing k baad hmm splitting perfom krte hh  dependent value - Y mm  independent values  X m
x=df.drop(["area"],axis=1)
#area apan ka dependent variable hhh toh usko drop krke baki sare columns(axis=1) X  m  daal diye

# %%
x.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain'],
#       dtype='object')

# %%
y=df[["area"]]

# %%
y
# Out:
#       area
# 0     0.00
# 1     0.00
# 2     0.00
# 3     0.00
# 4     0.00
# 5     0.00
# 6     0.00
# 7     0.00
# 8     0.00
# 9     0.00
# 10    0.00
# 11    0.00
# 12    0.00
# 13    0.00
# 14    0.00
# 15    0.00
# 16    0.00
# 17    0.00
# 18    0.00
# 19    0.00
# 20    0.00
# 21    0.00
# 22    0.00
# 23    0.00
# 24    0.00
# 25    0.00
# 26    0.00
# 27    0.00
# 28    0.00
# 29    0.00
# ..     ...
# 487  16.40
# 488  46.70
# 489   0.00
# 490   0.00
# 491   0.00
# 492   0.00
# 493  43.32
# 494   8.59
# 495   0.00
# 496   2.77
# 497  14.68
# 498  40.54
# 499  10.82
# 500   0.00
# 501   0.00
# 502   0.00
# 503   1.95
# 504  49.59
# 505   5.80
# 506   0.00
# 507   0.00
# 508   0.00
# 509   2.17
# 510   0.43
# 511   0.00
# 512   6.44
# 513  54.29
# 514  11.16
# 515   0.00
# 516   0.00
#
# [517 rows x 1 columns]

# %% [markdown]
# ## heatmap  for showing the best columns for prediction

# %%
plt.figure(figsize=(10,10))
sns.heatmap(x.corr(),cmap='Reds',annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.head()
# Out:
#      X  Y  month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain
# 390  7  4      3    1  84.7    9.5   58.3   4.1   7.5  71   6.3   0.0
# 5    8  6      1    3  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0
# 141  1  2      1    6  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0
# 268  3  4      1    5  92.1  152.6  658.2  14.3  21.0  32   3.1   0.0
# 135  3  5      1    2  93.5  139.4  594.2  20.3  17.6  52   5.8   0.0

# %%
y_train.head()
# Out:
#      area
# 390  9.96
# 5    0.00
# 141  0.55
# 268  0.00
# 135  0.00

# %%
x_test
# Out:
#      X  Y  month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain
# 213  7  3      7    1  87.6   52.2  103.8   5.0  11.0  46   5.8   0.0
# 435  2  5      5    2  90.8   84.7  376.6   5.6  23.8  51   1.8   0.0
# 343  8  6     11    1  91.5  130.1  807.1   7.5  15.9  51   4.5   0.0
# 230  4  4     11    6  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0
# 171  8  6      1    6  85.6   90.4  609.6   6.6  17.4  50   4.0   0.0
# 15   6  5     11    0  93.3  141.2  713.9  13.9  22.9  44   5.4   0.0
# 162  6  3      7    2  90.6   50.1  100.4   7.8  15.2  31   8.5   0.0
# 489  4  4      1    6  95.1  141.3  605.8  17.7  20.6  58   1.3   0.0
# 381  8  6      1    4  90.7  194.1  643.0   6.8  16.2  63   2.7   0.0
# 96   3  4      3    2  83.9    8.0   30.2   2.6  12.7  48   1.8   0.0
# 249  3  4      1    6  93.1  157.3  666.7  13.5  21.7  40   0.4   0.0
# 278  4  4      2    1  85.4   25.4  349.7   2.6   4.6  21   8.5   0.0
# ...

# %%
x_train.describe()
# Out:
#                 X           Y       month         day        FFMC         DMC  \
# count  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000
# mean     4.595568    4.279778    5.761773    2.739612   90.732964  111.099169
# std      2.341031    1.243586    4.299713    1.886740    5.587625   64.584362
# min      1.000000    2.000000    0.000000    0.000000   18.700000    1.100000
# 25%      3.000000    4.000000    1.000000    1.000000   90.300000   56.700000
# 50%      4.000000    4.000000    6.000000    3.000000   91.600000  108.400000
# 75%      7.000000    5.000000   11.000000    4.000000   92.900000  142.400000
# max      9.000000    9.000000   11.000000    6.000000   96.200000  290.000000
#
#                DC         ISI        temp          RH        wind        rain
# count  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000
# mean   541.738504    9.054017   18.861773   43.955679    3.948476    0.026593
# ...

# %%
#yeh sara step
#from sklearn.preprocessing import OneHotEncoder
#data preprocessing m agar apne p null values hh toh hmm median se replace kr rhe hh by using this onehot encoder

# %%
#aa=OneHotEncoder(n_values="median")
#aur agar apne ko null values drop krna ho toh   aur yeh pandas library m hh toh
#df=pd.drop_na(axis=0 or 1) 0 for the rows and 1 for columns

# %%
#df=aa.fit_transform(df)
#aur fir vapsi apan df m dalwa rhe

# %%
from sklearn.linear_model import LogisticRegression

# %%
ss=LogisticRegression()

# %%
ss1=ss.fit(x_train,y_train)
# Out:
# C:\Users\prate\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\prate\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-e7db9f5c47ec> in <module>
# ----> 1 ss1=ss.fit(x_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
#    1532                          accept_large_sparse=solver != 'liblinear')
# ...

# %%
1
# Out:
# 1
